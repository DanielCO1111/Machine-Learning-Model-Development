# %% [markdown]
# ## Classification Analysis for University Admissions and Quality Assurance
#
# This module demonstrates the implementation and application of logistic regression to real-world classification challenges. The analysis is divided into two primary case studies: university admissions prediction and industrial quality assurance for microchips.
#
# The implementation utilizes [`numpy`](http://www.numpy.org/) for efficient matrix operations and [`matplotlib`](https://matplotlib.org/) for data visualization and decision boundary analysis.

# %% [markdown]
# ### Predictive Modeling for University Admissions
#
# This section focuses on developing a logistic regression model to estimate the probability of university admission based on applicant exam scores. By leveraging historical data from previous applicants, the model identifies patterns that correlate exam performance with admission outcomes. The objective is to build a robust classifier that can accurately predict the status of new applicants.
#
# The following cell loads the dataset and prepares the feature matrix and target labels:

# %%
import pandas as pd
import numpy as np

# %%
students = pd.read_csv("ex2data1.txt", names=["First_Exam", "Second_Exam", "Admission_Status"])
# type casting from pandas series and pandas dataframe to numpy array
X = np.array(students[["First_Exam", "Second_Exam"]])
y = np.array(students["Admission_Status"])
# size of dataset
number_of_samples = y.size
# size of X matrix, m= rows, n= features
m,n = X.shape
print('size of samples: {}'.format(number_of_samples))

# %%
students.head()

# %% [markdown]
# ### Exploratory Data Analysis
#
# Visualizing the dataset is a critical first step in understanding the underlying distributions and potential separability of the classes. The following plot illustrates the relationship between the two exam scores and the admission status.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Core Algorithm Implementation
#
# #### The Sigmoid Function
#
# The logistic regression hypothesis is defined as:
#
# $$ h_\theta(x) = g(\theta^T x)$$
#
# where $g$ is the sigmoid function:
#
# $$g(z) = \frac{1}{1+e^{-z}}$$.
#
# The sigmoid function maps any real-valued number into the range [0, 1], making it ideal for probability estimation. The implementation below is designed to handle both scalar and vector/matrix inputs element-wise.

# %%
def sigmoid(z):
    """
    Compute sigmoid function given the input z.

    Parameters
    ----------
    z : array_like
        The input to the sigmoid function. This can be a 1-D vector
        or a 2-D matrix.

    Returns
    -------
    g : array_like
        The computed sigmoid function. g has the same shape as z, since
        the sigmoid is computed element-wise on z.
    """
    g = 1 / (1 + np.exp(-z))
    return g

# %%
# test sigmoid function
z = 0
g = sigmoid(z)

print("Actual value of sigmoid(0) should be 0.5")
print("Computed value of sigmoid(0) is {sigmoid}".format(sigmoid= g))

# %% [markdown]
# #### Cost Function and Gradient Descent
#
# The next step involves implementing the objective function and its gradient. The cost function $J(\theta)$ measures the performance of the model, while the gradient provides the direction for parameter updates during optimization.
#
# The cost function for logistic regression is defined as:
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^m \left[ -y^{(i)}\log \left( h_\theta \left(x^{(i)} \right) \right) - \left( 1 - y^{(i)} \right) \log \left( 1 - h_\theta \left( x^{(i)} \right) \right) \right]$$
#
# and the gradient of the cost is a vector of the same length as $\theta$ where the $j^{th}$
# element (for $j = 0, 1, \cdots , n$) is defined as follows:
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^m \left( h_\theta \left( x^{(i)} \right) - y^{(i)} \right) x_j^{(i)} $$
#
# Note that while this gradient looks identical to the linear regression gradient, the formula is actually different because linear and logistic regression have different definitions of $h_\theta(x)$. An intercept term (bias) is added to the feature matrix $X$ prior to training.

# %%
# add intercept term to martix X
X = np.concatenate([np.ones((len(X), 1)), X], axis= 1)
### make  theta_0 as the bias term

# %% [markdown]
# Note that the parameter $\theta_0$ represents the bias term in the model's weights.
# Now, complete the code for the function `cost_function` to return the cost value and define `gradient_descent` to reteun gradient. Recall that the cost function in logistic regression is
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^{m} \left[ -y^{(i)} \log\left(h_\theta\left( x^{(i)} \right) \right) - \left( 1 - y^{(i)}\right) \log \left( 1 - h_\theta\left( x^{(i)} \right) \right) \right]$$
#
# and the gradient of the cost is a vector of the same length as $\theta$ where the $j^{th}$
# element (for $j = 0, 1, \cdots , n$) is defined as follows:
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^m \left( h_\theta \left( x^{(i)} \right) - y^{(i)} \right) x_j^{(i)} $$
#
# Note that while this gradient looks identical to the linear regression gradient, the formula is actually different because linear and logistic regression have different definitions of $h_\theta(x)$.

# %%
def cost_function(theta, X, y):
    """
    Compute cost_function for logistic regression.

    Parameters
    ----------
    theta : array_like
        The parameters for logistic regression. This a vector
        of shape (n+1, ).

    X : array_like
        The input dataset of shape (m x n+1) where m is the total number
        of data points and n is the number of features. We assume the
        intercept has already been added to the input.

    y : arra_like
        Labels for the input. This is a vector of shape (m, ).

    Returns
    -------
    J : float
        The computed value for the cost function.
    """

    m = y.size
    h = sigmoid(X @ theta)
    epsilon = 1e-5
    return -(1/m) * (np.dot(y, np.log(h + epsilon)) + np.dot((1 - y), np.log(1 - h + epsilon)))

# %%
def gradient_descent(theta, X, y):
    """
    Compute gradient_descent for logistic regression.

    Parameters
    ----------
    theta : array_like
        The parameters for logistic regression. This a vector
        of shape (n+1, ).

    X : array_like
        The input dataset of shape (m x n+1) where m is the total number
        of data points and n is the number of features. We assume the
        intercept has already been added to the input.

    y : arra_like
        Labels for the input. This is a vector of shape (m, ).

    Returns
    -------
    grad : array_like
        A vector of shape (n+1, ) which is the gradient of the cost
        function with respect to theta, at the current values of theta.
    """
    m = y.size
    sig = sigmoid(np.dot(X,theta))
    sum = sig -y 
    grad = np.dot(sum,X)/ m

    return grad

# %%
### check the gradient and with theta=np.zeros(n+1)

# %%
initial_theta = np.zeros(n+1)
grad = gradient_descent(initial_theta, X, y)
cost = cost_function(initial_theta,X,y)
print("Shape of cost value is: {}".format(cost))
print("Shape of grad is: {}".format(grad.shape))

# %% [markdown]
# ### Stochastic Gradient Descent Optimization
#
# The model parameters are optimized using Stochastic Gradient Descent (SGD). This approach iteratively updates the weights based on individual samples, allowing for efficient convergence even on larger datasets. The following implementation includes a shuffling mechanism to ensure unbiased learning across epochs.

# %%
def train_using_sgd(theta, X, y, learning_rate=0.01, epochs=500):
    """
    Perform stochastic gradient descent to train the logistic regression model.
    """
    m = len(X)
    bestTheta = theta.copy()
    best_cost = float('inf')

    for epoch in range(epochs):
        indices = np.random.permutation(m)
        Xshuffled = X[indices]
        yshuffled = y[indices]

        for i in range(m):
            xi = Xshuffled[i].reshape(1, -1)
            yi = yshuffled[i]

            z = np.dot(xi, theta)
            h = sigmoid(z)

            gradient = np.dot(xi.T, (h - yi))
            theta -= learning_rate * gradient

        cost = cost_function(theta, X, y)
        if cost < best_cost:
            best_cost = cost
            bestTheta = theta.copy()

    return bestTheta

# Example usage:
# Assuming you have X, y, and theta initialized appropriately
# Train the logistic regression model using stochastic gradient descent
theta = np.zeros(n+1)
theta_optimized = train_using_sgd(theta, X, y)

# %%
# Print results
print("Optimized theta is: {}".format(theta_optimized))

# Calculate cost
optimize_cost = cost_function(theta_optimized, X, y)
print("Optimized Cost value is: {:.4f}".format(optimize_cost))

# %% [markdown]
# ### Decision Boundary Visualization
#
# The following plot visualizes the decision boundary learned by the model. This boundary represents the threshold where the classifier distinguishes between 'Accepted' and 'Declined' status based on the input features.

# %%
def plot_data(X, y):
    plt.scatter(X[y == 1][:, 1], X[y == 1][:, 2], color='green', label='Accepted')
    plt.scatter(X[y == 0][:, 1], X[y == 0][:, 2], color='red', marker='x', label='Declined')
    plt.xlabel("First Exam Score")
    plt.ylabel("Second Exam Score")
    plt.legend()

def plot_decision_boundary(theta, X):
    x_values = [np.min(X[:, 1]), np.max(X[:, 1])]
    y_values = -(theta[0] + np.dot(theta[1], x_values)) / theta[2]
    plt.plot(x_values, y_values, label='Decision Boundary')

plot_data(X, y)
plot_decision_boundary(theta_optimized, X)
plt.show()

# %% [markdown]
# #### Model Evaluation and Performance Metrics
#
# Once the parameters are optimized, the model's predictive power can be assessed. Training accuracy is calculated by comparing the predicted labels against the ground truth. Additionally, the ROC curve and AUC score provide a comprehensive view of the classifier's performance across different thresholds.
#
# For a student with an Exam 1 score of 53 and an Exam 2 score of 94, the model estimates the following admission probability:

# %%
def predict(theta, X):
    """
    Predict whether the label is 0 or 1 using learned logistic regression.
    Computes the predictions for X using a threshold at 0.5
    (i.e., if sigmoid(theta.T*x) >= 0.5, predict 1)

    Parameters
    ----------
    theta : array_like
        Parameters for logistic regression. A vecotor of shape (n+1, ).

    X : array_like
        The data to use for computing predictions. The rows is the number
        of points to compute predictions, and columns is the number of
        features.

    Returns
    -------
    p : array_like
        Predictions and 0 or 1 for each row in X.
    """
    probability = sigmoid(np.dot(X, theta))
    predicted = (probability >= 0.5).astype(int)
    return predicted

# %%
def accuracy(y_pred, y):
    """
    check prediction accuracy with comparison between predict and actual value
    if two parameter(predicted and actual value) are equal diff will be 0 and
    otherwise will be 1. count of nonzero devided by len of diff is errors. 1 minus
    error is our prediction accuracy

    Parameters
    ----------
    y_pred : array_like
        Predicted values that output of predict function.

    y : array_like
        Actual value of data, (Labels)

    Returns
    -------
    number : float
        model accuracy percentage
    """
    diff = y_pred - y
    error = np.count_nonzero(diff) / len(diff)
    accuracy = 1 - error
    return accuracy

# %% [markdown]
# After you have completed the code in `predict`, we proceed to report the training accuracy of your classifier by computing the percentage of examples it got correct.

# %%
# Predict probability for a student with score 53 on exam 1
# and score 94 on exam 2
student = np.array([1, 53, 94])  
probability = sigmoid(student @ theta_optimized)
print(f"Admission probability: {probability:.4f}")

# Predict on the training set
y_pred = predict(theta_optimized, X)
train_accuracy = accuracy(y_pred, y)
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")

# %% [markdown]
# ### Performance Analysis: AUC and ROC Curve
#
# To further validate the model, the Receiver Operating Characteristic (ROC) curve and Area Under the Curve (AUC) are analyzed. these metrics provide insights into the classifier's ability to distinguish between classes across various probability thresholds.

# %%
# Assuming sigmoid function and other previous definitions are available
def calculate_probabilities(X, theta):
    return sigmoid(np.dot(X, theta))

def calculate_tpr_fpr(y_true, probabilities, threshold):
    # Convert probabilities to binary decisions based on the threshold
    predictions = (probabilities >= threshold).astype(int)
    
    # True positives, false positives, true negatives, false negatives
    tp = np.sum((predictions == 1) & (y_true == 1))
    fp = np.sum((predictions == 1) & (y_true == 0))
    tn = np.sum((predictions == 0) & (y_true == 0))
    fn = np.sum((predictions == 0) & (y_true == 1))
    
    tpr = tp / (tp + fn) if (tp + fn) != 0 else 0
    fpr = fp / (fp + tn) if (fp + tn) != 0 else 0
    
    return tpr, fpr

def plot_roc_curve(X, y, theta):
    probabilities = calculate_probabilities(X, theta)
    thresholds = np.linspace(0, 1, 100)
    
    tprs = []
    fprs = []
    
    for threshold in thresholds:
        tpr, fpr = calculate_tpr_fpr(y, probabilities, threshold)
        tprs.append(tpr)
        fprs.append(fpr)
    
    # Plotting the ROC curve
    plt.figure(figsize=(8, 6))
    plt.plot(fprs, tprs, label='ROC Curve', color='blue')
    plt.plot([0, 1], [0, 1], 'r--', label='Random Classifier')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.show()
    
    # Calculate AUC using the trapezoidal rule
    auc = np.trapezoid(tprs, fprs)
    print("Area Under Curve (AUC):", abs(auc))

# Use the function to plot ROC and calculate AUC
plot_roc_curve(X, y, theta_optimized)

# %% [markdown]
# ### Quality Assurance Classification with Regularization
#
# This section extends the logistic regression framework to handle complex, non-linearly separable datasets using regularization. The case study involves predicting whether microchips from a fabrication plant pass quality assurance (QA) based on two different test results.
#
# The dataset represents microchips that undergo various tests. The goal is to develop a model that can reliably distinguish between functional and defective units, even when the decision boundary is non-linear.
#
# Data is loaded from the CSV source below:

# %%
microchips= pd.read_csv("ex2data2.txt", names=["First_Test", "Second_Test", "Status"])
# type casting from pandas series and pandas dataframe to numpy array
X = np.array(microchips[["First_Test", "Second_Test"]])
y = np.array(microchips["Status"])
# size of dataset
number_of_samples = y.size
# size of X matrix, m= rows, n= features
m,n = X.shape
print('size of samples: {}'.format(number_of_samples))

# %% [markdown]
# ### Exploratory Data Analysis
#
# The following visualization highlights the distribution of positive (accepted) and negative (rejected) microchip samples based on their test scores.

# %%
plt.scatter(X[y==1][:,0],X[y==1][:,1],color='green',label='Accepted')
plt.scatter(X[y==0][:,0],X[y==0][:,1],color='red', marker='x',label='declined')
plt.xlabel("First Exam Score")
plt.ylabel("second Exam Score")
plt.legend()
plt.show()

# %% [markdown]
# ### Feature Mapping and Non-Linear Boundaries
#
# The initial visualization reveals that the dataset cannot be separated by a simple linear boundary. To address this, the feature space is expanded using polynomial mapping. The `map_feature` function transforms the original two features into all polynomial terms up to the sixth power:
#
# $$ \text{map_feature}(x) = \begin{bmatrix} 1 & x_1 & x_2 & x_1^2 & x_1 x_2 & x_2^2 & x_1^3 & \dots & x_1 x_2^5 & x_2^6 \end{bmatrix}^T $$
#
# This transformation results in a 28-dimensional feature vector, allowing the logistic regression classifier to learn a much more complex, non-linear decision boundary. However, this increased expressiveness makes the model more susceptible to overfitting, which is addressed in the following steps through regularization.

# %% [markdown]
# ### Feature Mapping Implementation

# %%
def map_feature(X1, X2, degree=6):
    """
    Maps the two input features to quadratic features used in the regularization exercise.

    Returns a new feature array with more features, comprising of
    X1, X2, X1.^2, X2.^2, X1*X2, X1*X2.^2, etc..

    Parameters
    ----------
    X1 : array_like
        A vector of shape (m, 1), containing one feature for all examples.

    X2 : array_like
        A vector of shape (m, 1), containing a second feature for all examples.
        Inputs X1, X2 must be the same size.

    degree: int, optional
        The polynomial degree.

    Returns
    -------
    : array_like
        A matrix of of m rows, and columns depend on the degree of polynomial.
    """
    if X1.ndim == 0:
        X1 = np.array([X1])
        X2 = np.array([X2])

    out = np.ones((X1.shape[0], 1))  # Start with a column of ones (bias term)

    for i in range(1, degree + 1):
        for j in range(i + 1):
            term = (X1 ** (i - j)) * (X2 ** j)
            out = np.hstack((out, term.reshape(-1, 1)))

    return out

# %%
X = map_feature(X[:,0], X[:,1])

# %% [markdown]
# ### Regularized Cost Function and Gradient
#
# To prevent overfitting in the high-dimensional feature space, a regularization term is added to the cost function. This penalizes large parameter values, encouraging a simpler model.
#
# The regularized cost function is defined as:
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^m \left[ -y^{(i)}\log \left( h_\theta \left(x^{(i)} \right) \right) - \left( 1 - y^{(i)} \right) \log \left( 1 - h_\theta \left( x^{(i)} \right) \right) \right] + \frac{\lambda}{2m} \sum_{j=1}^n \theta_j^2 $$
#
# The gradient updates are modified accordingly, ensuring the bias term $\theta_0$ is not regularized:
#
# $$ \frac{\partial J(\theta)}{\partial \theta_0} = \frac{1}{m} \sum_{i=1}^m \left( h_\theta \left(x^{(i)}\right) - y^{(i)} \right) x_j^{(i)} \qquad \text{for } j =0 $$
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \left( \frac{1}{m} \sum_{i=1}^m \left( h_\theta \left(x^{(i)}\right) - y^{(i)} \right) x_j^{(i)} \right) + \frac{\lambda}{m}\theta_j \qquad \text{for } j \ge 1 $$
#
# The model is optimized using Gradient Descent with Momentum to improve convergence speed and stability. Performance is evaluated across different regularization strengths ($\lambda$).

# %%
def cost_function_gradient_descent_regularized(theta, X, y, lambda_):
    """
    Compute cost and gradient for logistic regression with regularization.

    Parameters
    ----------
    theta : array_like
        Logistic regression parameters. A vector with shape (n, ). n is
        the number of features including any intercept. If we have mapped
        our initial features into polynomial features, then n is the total
        number of polynomial features.

    X : array_like
        The data set with shape (m x n). m is the number of examples, and
        n is the number of features (after feature mapping).

    y : array_like
        The data labels. A vector with shape (m, ).

    lambda_ : float
        The regularization parameter.

    Returns
    -------
    J : float
        The computed value for the regularized cost function.

    grad : array_like
        A vector of shape (n, ) which is the gradient of the cost
        function with respect to theta, at the current values of theta.
    """
    # Initialize some useful values
    m = y.size  # number of training examples
    
    # Compute hypothesis
    h = sigmoid(X @ theta)
    
    # Compute cost
    epsilon = 1e-5  # small number to avoid log(0)
    cost = (-1/m) * (y.T @ np.log(h + epsilon) + (1 - y).T @ np.log(1 - h + epsilon)) 
    reg_cost = (lambda_ / (2 * m)) * np.sum(np.square(theta[1:]))  # regularization (skip theta_0)
    J = cost + reg_cost
    
    # Compute gradient
    grad = (1/m) * (X.T @ (h - y))
    reg_grad = (lambda_ / m) * theta
    reg_grad[0] = 0  # don't regularize theta_0
    grad += reg_grad
    
    return J, grad

    # =============================================================

# %% [markdown]
# ### Regularized Optimization with Momentum
#
# The regularized model is trained using a gradient descent algorithm enhanced with momentum. This technique helps accelerate the optimization process and navigate local minima more effectively. The impact of the regularization parameter ($\lambda$) on the decision boundary is explored below.

# %%
def train_using_momentum(theta, X, y, learning_rate=0.1, beta=0.9, lambda_=1, epochs=1000):
    """
    Perform gradient descent with momentum to train the Regularized logistic regression model.
    """
    m = y.size
    v = np.zeros(theta.shape)  # Initialize momentum vector

    for epoch in range(epochs):
        # Compute cost and gradient
        cost, grad = cost_function_gradient_descent_regularized(theta, X, y, lambda_)

        # Update momentum
        v = beta * v + (1 - beta) * grad

        # Update parameters
        theta = theta - learning_rate * v

    return theta

# %%
# Initialize theta according to the number of features
theta_init = np.zeros(X.shape[1])

# Train model using momentum
theta_optimized = train_using_momentum(theta_init, X, y, learning_rate=0.1, beta=0.9, lambda_=1, epochs=1000)

# Make predictions
model_predicted = predict(theta_optimized, X)

# Print results
print("Train Accuracy: {:.1f}".format((np.mean(model_predicted == y) * 100)))
print("Expected accuracy (with lambda = 1): 83.1 % (approx)\n")

# %% [markdown]
# ### Decision Boundary Analysis ($\lambda = 1$)
#
# Visualizing the effect of moderate regularization on the decision boundary.

# %%
pos = y == 1
neg = y == 0

# %%
# Plot decision boundary for lambda = 1

pos = y == 1
neg = y == 0

plt.figure(figsize=(8,6))


plt.scatter(X[pos, 1], X[pos, 2], c='b', marker='+', label='Accepted')
plt.scatter(X[neg, 1], X[neg, 2], c='r', marker='o', label='Rejected')


u = np.linspace(-1, 1.5, 50)
v = np.linspace(-1, 1.5, 50)
z = np.zeros((u.size, v.size))


for i in range(u.size):
    for j in range(v.size):
        features = map_feature(np.array([u[i]]), np.array([v[j]]))
        z[i, j] = features @ theta_optimized

z = z.T 

plt.contour(u, v, z, levels=[0], linewidths=2)
plt.xlabel('Microchip Test 1')
plt.ylabel('Microchip Test 2')
plt.title('Decision Boundary (lambda = 1)')
plt.legend()
plt.show()

# %% [markdown]
# ### Decision Boundary Analysis ($\lambda = 0$)
#
# Visualizing the effect of zero regularization, which often leads to overfitting on complex datasets.

# %%
# Compute accuracy on our training set
theta = np.random.uniform(0, 0.1, size=28)
learning_rate = 0.01
beta = 0.95
lmbda = 0
theta_opt = train_using_momentum(theta, X, y, learning_rate, beta, lmbda)
model_predicted = predict(theta_opt, X)

def plot_decision_boundary(theta, X, y, degree=6):
    # Define the grid range
    u = np.linspace(-1, 1.5, 50)
    v = np.linspace(-1, 1.5, 50)
    z = np.zeros((len(u), len(v)))

    # Evaluate z = theta*x over the grid
    for i, ui in enumerate(u):
        for j, vj in enumerate(v):
            mapped_features = map_feature(np.array([ui]), np.array([vj]), degree)
            # Ensure mapped_features is a 1D array
            mapped_features = np.squeeze(mapped_features)
            z[i, j] = np.dot(mapped_features, theta)

    z = z.T  # important to transpose z before calling contour

    # Plot z = 0
    plt.contour(u, v, z, levels=[0], linewidths=2, colors='g')
    plt.scatter(X[:, 1], X[:, 2], c=y, cmap=plt.cm.coolwarm)

    # Label axes
    plt.xlabel("Microchip Test 1")
    plt.ylabel("Microchip Test 2")
    plt.legend(['Decision Boundary', 'y = 1', 'y = 0'])
    plt.title("Plot of decision boundary")
    plt.show()

# Assume theta_opt and other variables are defined and correct
plot_decision_boundary(theta_opt, X, y)
print(theta_opt)
